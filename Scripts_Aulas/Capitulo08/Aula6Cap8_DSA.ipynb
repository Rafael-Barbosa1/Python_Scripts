# %% [markdown]
# ## Gráficos

# %%
import matplotlib as mpl 
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
mpl.__version__
# Out:
# '3.2.1'

# %%
plt.plot([1, 3, 5], [2, 5, 7])
plt.show()

# %%
plt.plot([1, 3, 5], [2, 5, 7])
plt.xlabel('Variável X')
plt.ylabel('Variável Y')
plt.show()

# %%
plt.plot([1, 3, 5], [2, 5, 7], label = "Uma linha aleatória")
plt.xlabel('Variável X')
plt.ylabel('Variável Y')
plt.legend()
plt.show()

# %% [markdown]
# ### Gráfico de Barras

# %%
x = [2, 4, 6, 8, 10]

y = [6, 7, 8, 2, 4]

# %%
plt.bar(x, y, label = "Barras", color = "r")
plt.legend()
plt.show()

# %%
x2 = [1, 3, 5, 7, 9]

y2 = [7, 8, 2, 4, 2]

# %%
plt.bar(x, y, label = "Barra1", color = "r")
plt.bar(x2, y2, label = "Barra12", color = "y")
plt.legend()
plt.show()

# %% [markdown]
# ### Scatterplot

# %%
x = list(range(1, 9))

y = [5, 2, 4, 5, 6, 8, 4, 8]

x
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
plt.scatter(x, y , label = "Pontos", color = "r")
plt.legend()
pltt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-25660f65f9be> in <module>
#       1 plt.scatter(x, y , label = "Pontos", color = "r")
#       2 plt.legend()
# ----> 3 pltt.show()
#
# NameError: name 'pltt' is not defined

# %% [markdown]
# ### Pie Chart

# %%
fatia = [7, 2, 2, 13]
atividades = ["dormir", "comer", "trabalhar", "passear"]

# %%
plt.pie(fatia, labels = atividades)
# Out:
# ([<matplotlib.patches.Wedge at 0x4d54520>,
#   <matplotlib.patches.Wedge at 0x4d54490>,
#   <matplotlib.patches.Wedge at 0x4d541f0>,
#   <matplotlib.patches.Wedge at 0x4d5d7a8>],
#  [Text(0.6696375991452626, 0.8726886534216935, 'dormir'),
#   Text(-0.5499999479716446, 0.9526279742014657, 'comer'),
#   Text(-0.95262792270675, 0.5500000371631103, 'trabalhar'),
#   Text(-0.14357877740594213, -1.0905893519921306, 'passear')])
